# %% [markdown]
# <a href="https://colab.research.google.com/github/fajrunwm/30-day-map-challenge-2022/blob/main/U_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # U-Net
#
# U-Net application for urban settlement segregation in BSD, Tangerang City, Indonesia

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Connect to Google Drive
#
# Mounting Google Drive to access our dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Essential Libraries

# %%
import os  # Operating system interfaces for file handling
import numpy as np  # Numerical operations on large arrays
import tensorflow as tf  # TensorFlow for deep learning
import random  # Generate random numbers
import matplotlib.pyplot as plt  # Plotting and visualization

from PIL import Image
from sklearn.model_selection import train_test_split  # Splitting the dataset into training and validation sets
from tensorflow.keras.utils import to_categorical  # Convert class vectors to binary class matrices
from tensorflow.keras.utils import plot_model # For plotting the model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate  # Layers for building the U-Net model
from tensorflow.keras.models import Model  # Class to create a Keras model
from tensorflow.keras.optimizers import Adam  # Adam optimizer
from tensorflow.keras.callbacks import EarlyStopping  # Stop training when a monitored metric has stopped improving
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array  # Functions to load and process images

# %% [markdown]
# ## Data Loading

# %%
# Function to load images and masks from directories
def load_images_and_masks(image_dir, mask_dir, target_size=(256, 256)):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.tif')])
    mask_files = sorted([f for f in os.listdir(mask_dir) if f.endswith('.png')])

    images = []
    masks = []

    for img_file, mask_file in zip(image_files, mask_files):
        img_path = os.path.join(image_dir, img_file)
        mask_path = os.path.join(mask_dir, mask_file)

        img = load_img(img_path, target_size=target_size)
        mask = load_img(mask_path, target_size=target_size, color_mode="grayscale")

        img = img_to_array(img) / 255.0  # Normalize image
        mask = img_to_array(mask)  # Do not normalize mask for discrete class values

        images.append(img)
        masks.append(mask)

    return np.array(images), np.array(masks)

# %%
# Defining the image, mask, and label directories
image_dir = 'drive/MyDrive/Colab Notebooks/GEOG0105/ML_UIS/dataset_v4/images'
mask_dir = 'drive/MyDrive/Colab Notebooks/GEOG0105/ML_UIS/dataset_v4/masks'
images, masks = load_images_and_masks(image_dir, mask_dir)

# %%
# Verify the lengths of images and masks
print(f"Number of images: {len(images)}")
print(f"Number of masks: {len(masks)}")
# Out:
# Number of images: 15
# Number of masks: 15

# %%
# Verify File Existence (optional)
# List files in directories
image_files = [f for f in os.listdir(image_dir) if f.endswith('.tif')]
mask_files = [f for f in os.listdir(mask_dir) if f.endswith('.png')]

# Print out the lists of files
print("Image files:", image_files)
print()
print("Mask files:", mask_files)
# Out:
# Image files: ['patch_2_6.tif', 'patch_0_9.tif', 'patch_0_1.tif', 'patch_7_5.tif', 'patch_7_14.tif', 'patch_6_0.tif', 'patch_7_0.tif', 'patch_9_0.tif', 'patch_9_10.tif', 'patch_9_5.tif', 'patch_0_4.tif', 'patch_0_6.tif', 'patch_0_5.tif', 'patch_6_13.tif', 'patch_7_12.tif']
#
# Mask files: ['mask_patch_0_9.png', 'mask_patch_6_0.png', 'mask_patch_6_13.png', 'mask_patch_9_10.png', 'mask_patch_2_6.png', 'mask_patch_0_1.png', 'mask_patch_0_6.png', 'mask_patch_0_4.png', 'mask_patch_7_14.png', 'mask_patch_7_5.png', 'mask_patch_7_12.png', 'mask_patch_9_5.png', 'mask_patch_7_0.png', 'mask_patch_0_5.png', 'mask_patch_9_0.png']

# %% [markdown]
# ## Check the Mask Values

# %%
# Iterate through all files in the directory
for filename in os.listdir(mask_dir):
    if filename.endswith('.png'):
        label_png = os.path.join(mask_dir, filename)
        lbl = np.asarray(Image.open(label_png))

        # Print information about the current mask image
        print(f'------------------------------------')
        print(f"Processing file: {filename}")
        print(f"Data type: {lbl.dtype}")
        print(f"Unique values: {np.unique(lbl)}")
        print(f"Shape: {lbl.shape}\n")
# Out:
# ------------------------------------
# Processing file: mask_patch_0_9.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_6_0.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_6_13.png
# Data type: uint8
# Unique values: [0 1 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_9_10.png
# Data type: uint8
# Unique values: [0 1]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_2_6.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_0_1.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_0_6.png
# Data type: uint8
# Unique values: [0 1 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_0_4.png
# Data type: uint8
# Unique values: [0 1 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_7_14.png
# Data type: uint8
# Unique values: [0 1]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_7_5.png
# Data type: uint8
# Unique values: [0 1]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_7_12.png
# Data type: uint8
# Unique values: [0 1 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_9_5.png
# Data type: uint8
# Unique values: [0 1]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_7_0.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_0_5.png
# Data type: uint8
# Unique values: [0 1 2]
# Shape: (256, 256)
#
# ------------------------------------
# Processing file: mask_patch_9_0.png
# Data type: uint8
# Unique values: [0 2]
# Shape: (256, 256)

# %% [markdown]
# ## Debugging Unique Classes in Masks

# %%
# Check unique values in masks and shape of masks
unique_values = np.unique(masks)
print("Unique values in masks:", unique_values)
print("Shape of masks array:", masks.shape)

# Ensure unique values in masks do not exceed the number of classes
n_classes = len(unique_values)
print("Number of classes:", n_classes)
# Out:
# Unique values in masks: [0. 1. 2.]
# Shape of masks array: (15, 256, 256, 1)
# Number of classes: 3

# %%
# Determine Number of Unique Classes
masks_cat = to_categorical(masks, num_classes=n_classes)

## Optionally split into train/validation/test sets
x_train, x_val, y_train, y_val = train_test_split(images,
                                                  masks_cat,
                                                  test_size=0.2, # adjust between 0.2 to 0.3
                                                  random_state=42) # adjust but mostly 42

# %% [markdown]
# # U-Net Architecture

# %% [markdown]
# ## Model Building

# %%
# Function to build U-Net model
def unet_model(input_size=(256, 256, 3), num_classes=3):
    inputs = Input(input_size)

    # Down-sampling path
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)

    # Up-sampling path
    up6 = UpSampling2D(size=(2, 2))(conv5)
    up6 = concatenate([up6, conv4])
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = concatenate([up7, conv3])
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = concatenate([up8, conv2])
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = UpSampling2D(size=(2, 2))(conv8)
    up9 = concatenate([up9, conv1])
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    output_layer = Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[output_layer])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', iou])

    return model

# %% [markdown]
# ## IoU Metric

# %%
# Function to calculate Intersection over Union (IoU)
def iou(y_true, y_pred, smooth=1):
    y_true_f = tf.cast(tf.keras.backend.flatten(y_true), dtype=tf.float32)
    y_pred_f = tf.cast(tf.keras.backend.flatten(y_pred), dtype=tf.float32)

    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection

    iou_score = (intersection + smooth) / (union + smooth)

    return iou_score

# %% [markdown]
# ## Plot the Model Architecture

# %%
# Define dice_loss
def dice_loss(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)

# %%
# Define jaccard_loss
def jaccard_loss(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - (intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1)

# %%
model = unet_model()
model.compile(optimizer=Adam(learning_rate=0.0001), # adjust for better result (0.00001 to 0.001), the smaller the better
              loss='categorical_crossentropy',
              #loss=dice_loss,
              #loss=jaccard_loss,
              metrics=['accuracy', iou])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 64)         1792      ['input_2[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_19[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_20[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_4[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_21[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_22[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_5[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_23[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_24[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_25[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 512)          0         ['conv2d_26[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 1024)         9438208   ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 32, 32, 1024)         0         ['conv2d_28[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 32, 32, 1536)         0         ['up_sampling2d_4[0][0]',
#  )                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 512)          7078400   ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_29[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 64, 64, 512)          0         ['conv2d_30[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_5[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 256)          1769728   ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_31[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 128, 128, 256)        0         ['conv2d_32[0][0]']
#  g2D)
#
#  concatenate_6 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_6[0][0]',
#  )                                                                   'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 128)        442496    ['concatenate_6[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_33[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 256, 256, 128)        0         ['conv2d_34[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_7[0][0]',
#  )                                                                   'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_7[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 3)          195       ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 31379075 (119.70 MB)
# Trainable params: 31379075 (119.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
plot_model(model,
           to_file='unet_model.png',
           show_shapes=True,
           show_layer_names=True)

# Load and rotate the image array
image = plt.imread('unet_model.png')
image_rotated = np.rot90(image)

# Display the rotated image
plt.figure(figsize=(30, 15))
plt.imshow(image_rotated)
plt.title('U-Net Model Architecture')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Model Training

# %%
# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=10,  # adjust for better result (5, 10,  20), the higher can avoid overfitting
                               restore_best_weights=True)

# Data augmentation for training
datagen = ImageDataGenerator(rotation_range=20,  # adjust for better result (20, 30, 40)
                             width_shift_range=0.1,  # adjust for better result (0.1, 0.2)
                             height_shift_range=0.1,  # adjust for better result (0.1, 0.2)
                             horizontal_flip=True,
                             vertical_flip=True,
                             zoom_range=0.2)  # adjust for better result (0.2, 0.3)
datagen.fit(x_train)

# Train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=150, # adjust for better result (20, 30, ..., 100, 200), larger number can lead to better convergence and overfitting, vice versa
                    batch_size=16, # adjust for better result (4, 8, 16, 32, 64), smaller number requires more memory and longer training times, larger number requires more computational resources.
                    #callbacks=[early_stopping]
                    )

# Collecting IoU values
iou_values = history.history['iou']
val_iou_values = history.history['val_iou']
# Out:
# Epoch 1/150
# 1/1 [==============================] - 44s 44s/step - loss: 1.1054 - accuracy: 0.1785 - iou: 0.1984 - val_loss: 1.0993 - val_accuracy: 0.3193 - val_iou: 0.1999
# Epoch 2/150
# 1/1 [==============================] - 1s 696ms/step - loss: 1.0991 - accuracy: 0.3424 - iou: 0.1999 - val_loss: 1.0938 - val_accuracy: 0.6749 - val_iou: 0.2012
# Epoch 3/150
# 1/1 [==============================] - 1s 706ms/step - loss: 1.0938 - accuracy: 0.6879 - iou: 0.2012 - val_loss: 1.0872 - val_accuracy: 0.6923 - val_iou: 0.2028
# Epoch 4/150
# 1/1 [==============================] - 1s 699ms/step - loss: 1.0874 - accuracy: 0.7040 - iou: 0.2028 - val_loss: 1.0763 - val_accuracy: 0.6935 - val_iou: 0.2056
# Epoch 5/150
# 1/1 [==============================] - 1s 713ms/step - loss: 1.0767 - accuracy: 0.7062 - iou: 0.2055 - val_loss: 1.0524 - val_accuracy: 0.6938 - val_iou: 0.2122
# Epoch 6/150
# 1/1 [==============================] - 1s 705ms/step - loss: 1.0525 - accuracy: 0.7069 - iou: 0.2122 - val_loss: 0.9960 - val_accuracy: 0.6938 - val_iou: 0.2316
# Epoch 7/150
# Epoch 144/150
# 1/1 [==============================] - 1s 746ms/step - loss: 0.3261 - accuracy: 0.8306 - iou: 0.6594 - val_loss: 0.7907 - val_accuracy: 0.7292 - val_iou: 0.5213
# Epoch 145/150
# 1/1 [==============================] - 1s 737ms/step - loss: 0.3215 - accuracy: 0.8366 - iou: 0.6688 - val_loss: 0.7615 - val_accuracy: 0.7018 - val_iou: 0.5120
# Epoch 146/150
# 1/1 [==============================] - 1s 746ms/step - loss: 0.3235 - accuracy: 0.8483 - iou: 0.6651 - val_loss: 0.7990 - val_accuracy: 0.7251 - val_iou: 0.5208
# Epoch 147/150
# 1/1 [==============================] - 1s 844ms/step - loss: 0.3127 - accuracy: 0.8628 - iou: 0.6751 - val_loss: 0.7916 - val_accuracy: 0.7170 - val_iou: 0.5277
# Epoch 148/150
# 1/1 [==============================] - 1s 718ms/step - loss: 0.2917 - accuracy: 0.8746 - iou: 0.6890 - val_loss: 0.8142 - val_accuracy: 0.7214 - val_iou: 0.5278
# Epoch 149/150
# 1/1 [==============================] - 1s 743ms/step - loss: 0.2771 - accuracy: 0.8922 - iou: 0.6976 - val_loss: 0.8276 - val_accuracy: 0.7148 - val_iou: 0.5163
# Epoch 150/150
# 1/1 [==============================] - 1s 737ms/step - loss: 0.2732 - accuracy: 0.9013 - iou: 0.6977 - val_loss: 0.8869 - val_accuracy: 0.7175 - val_iou: 0.5348

# %% [markdown]
# # Visualisation of Training Results

# %% [markdown]
# ## Plot Training and Validation

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(13.5, 4.5))

ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.legend()
ax1.set_title('Loss over Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')

ax2.plot(history.history['accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax2.legend()
ax2.set_title('Accuracy over Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')

ax3.plot(history.history['iou'], label='Training IoU')
ax3.plot(history.history['val_iou'], label='Validation IoU')
ax3.legend()
ax3.set_title('IoU over Epochs')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('IoU')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualise Sample Predictions

# %%
def plot_sample_predictions(model, x_val, y_val, image_files):
    num_samples = len(x_val)

    for i in range(num_samples):
        x_sample = x_val[i]
        y_true = np.argmax(y_val[i], axis=-1)
        y_pred = np.argmax(model.predict(np.expand_dims(x_sample, axis=0)), axis=-1).squeeze()

        # Evaluate the model
        loss, accuracy, iou_score = model.evaluate(x_val, y_val)

        # Get the file name for the current sample
        file_name = image_files[i]

        fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 5))

        ax1.imshow(x_sample)
        ax1.set_title(f'{file_name}')
        ax1.axis('off')

        ax2.imshow(y_true)
        ax2.set_title('True Mask')
        ax2.axis('off')

        ax3.imshow(y_pred)
        ax3.set_title('Predicted Mask')
        ax3.axis('off')

        plt.show()

plot_sample_predictions(model, x_val, y_val, image_files)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 74ms/step - loss: 0.8869 - accuracy: 0.7175 - iou: 0.5348
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 75ms/step - loss: 0.8869 - accuracy: 0.7175 - iou: 0.5348
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 79ms/step - loss: 0.8869 - accuracy: 0.7175 - iou: 0.5348
